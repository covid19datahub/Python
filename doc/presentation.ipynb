# %% [markdown]
# # Covid-19 Data Hub
#
# Author: Martin Beneš
#
# [![](https://img.shields.io/pypi/v/covid19dh.svg?color=brightgreen)](https://pypi.org/pypi/covid19dh/) [![](https://img.shields.io/pypi/dm/covid19dh.svg?color=blue)](https://pypi.org/pypi/covid19dh/) [![DOI](https://joss.theoj.org/papers/10.21105/joss.02376/status.svg)](https://doi.org/10.21105/joss.02376) [![](https://github.com/covid19datahub/Python/workflows/utests_on_commit/badge.svg)](https://github.com/covid19datahub/Python)

# %% [markdown]
# The goal of [COVID-19 Data Hub](https://covid19datahub.io/) is to provide the research community with a unified data hub by collecting worldwide fine-grained case data, merged with exogenous variables helpful for a better understanding of COVID-19.
#
# Python package `covid19dh` brings the simple access to COVID-19 Data Hub. Acquiring the data is as simple as

# %%
from covid19dh import covid19
x,src = covid19(verbose = False)
x
# Out:
#         id       date    tests  confirmed  recovered  deaths  hosp  vent  icu  \
# 0      AFG 2020-01-22      NaN        0.0        NaN     0.0   NaN   NaN  NaN
# 1      AFG 2020-01-23      NaN        0.0        NaN     0.0   NaN   NaN  NaN
# 2      AFG 2020-01-24      NaN        0.0        NaN     0.0   NaN   NaN  NaN
# 3      AFG 2020-01-25      NaN        0.0        NaN     0.0   NaN   NaN  NaN
# 4      AFG 2020-01-26      NaN        0.0        NaN     0.0   NaN   NaN  NaN
# ...    ...        ...      ...        ...        ...     ...   ...   ...  ...
# 42705  ZWE 2020-08-22  90696.0     5893.0     4629.0   153.0   NaN   NaN  NaN
# 42706  ZWE 2020-08-23  91548.0     5930.0     4872.0   155.0   NaN   NaN  NaN
# 42707  ZWE 2020-08-24      NaN     6070.0     4950.0   155.0   NaN   NaN  NaN
# 42708  ZWE 2020-08-25      NaN     6196.0     4961.0   166.0   NaN   NaN  NaN
# 42709  ZWE 2020-08-26      NaN     6251.0     5001.0   179.0   NaN   NaN  NaN
#
#        population  ...  currency  administrative_area_level  \
# 0        37172386  ...       AFN                          1
# 1        37172386  ...       AFN                          1
# 2        37172386  ...       AFN                          1
# 3        37172386  ...       AFN                          1
# 4        37172386  ...       AFN                          1
# ...           ...  ...       ...                        ...
# 42705    14439018  ...       ZWD                          1
# 42706    14439018  ...       ZWD                          1
# 42707    14439018  ...       ZWD                          1
# 42708    14439018  ...       ZWD                          1
# 42709    14439018  ...       ZWD                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 0                      Afghanistan                          NaN
# 1                      Afghanistan                          NaN
# 2                      Afghanistan                          NaN
# 3                      Afghanistan                          NaN
# 4                      Afghanistan                          NaN
# ...                            ...                          ...
# 42705                     Zimbabwe                          NaN
# 42706                     Zimbabwe                          NaN
# 42707                     Zimbabwe                          NaN
# 42708                     Zimbabwe                          NaN
# 42709                     Zimbabwe                          NaN
#
#        administrative_area_level_3  latitude  longitude  key  \
# 0                              NaN      33.0       65.0  NaN
# 1                              NaN      33.0       65.0  NaN
# 2                              NaN      33.0       65.0  NaN
# 3                              NaN      33.0       65.0  NaN
# 4                              NaN      33.0       65.0  NaN
# ...                            ...       ...        ...  ...
# 42705                          NaN     -20.0       30.0  NaN
# 42706                          NaN     -20.0       30.0  NaN
# 42707                          NaN     -20.0       30.0  NaN
# 42708                          NaN     -20.0       30.0  NaN
# 42709                          NaN     -20.0       30.0  NaN
#
#        key_apple_mobility  key_google_mobility
# 0                     NaN                   AF
# 1                     NaN                   AF
# 2                     NaN                   AF
# 3                     NaN                   AF
# 4                     NaN                   AF
# ...                   ...                  ...
# 42705                 NaN                   ZW
# 42706                 NaN                   ZW
# 42707                 NaN                   ZW
# 42708                 NaN                   ZW
# 42709                 NaN                   ZW
#
# [42710 rows x 35 columns]

# %% [markdown]
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# `Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.`

# %% [markdown]
# ## Installation
#
# Installing is as easy as
#
# ```bash
# $ pip install covid19dh
# ```
#
# The package is regularly updated. Get the newest version with
#
# ```bash
# $ pip install --upgrade covid19dh
# ```

# %% [markdown]
# Acquired data and sources are in `pandas.DataFrame` format.

# %%
import pandas as pd # data lib

import matplotlib # visualization lib
import matplotlib.pyplot as plt
matplotlib.rc('figure', figsize=(12, 5))

# %% [markdown]
# ## Data acquiral
#
# The main motivation to use COVID-19 Data Hub: `COVID19` (R) or `covid19dh` (Python) is the simplicity of data acquiral.
#
# With a single call you can receive national statistics of COVID-19. The function lists the sources of the data on stdout.

# %%
usa,usa_src = covid19("USA") # read US data
# Out:
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.

# %% [markdown]
# You receive a Pandas dataframe of data.

# %%
usa
# Out:
#         id       date       tests  confirmed  recovered    deaths  hosp  vent  \
# 40312  USA 2020-01-22         NaN        1.0        NaN       0.0   NaN   NaN
# 40313  USA 2020-01-23         NaN        1.0        NaN       0.0   NaN   NaN
# 40314  USA 2020-01-24         NaN        2.0        NaN       0.0   NaN   NaN
# 40315  USA 2020-01-25         NaN        2.0        NaN       0.0   NaN   NaN
# 40316  USA 2020-01-26         NaN        5.0        NaN       0.0   NaN   NaN
# ...    ...        ...         ...        ...        ...       ...   ...   ...
# 40525  USA 2020-08-22  71086437.0  5667070.0  1985484.0  176350.0   NaN   NaN
# 40526  USA 2020-08-23  71700264.0  5701645.0  1997761.0  176800.0   NaN   NaN
# 40527  USA 2020-08-24  72382318.0  5739536.0  2020774.0  177245.0   NaN   NaN
# 40528  USA 2020-08-25  73016779.0  5777710.0  2053699.0  178486.0   NaN   NaN
# 40529  USA 2020-08-26         NaN  5821819.0  2084465.0  179708.0   NaN   NaN
#
#        icu  population  ...  currency  administrative_area_level  \
# 40312  NaN   326687501  ...       USN                          1
# 40313  NaN   326687501  ...       USN                          1
# 40314  NaN   326687501  ...       USN                          1
# 40315  NaN   326687501  ...       USN                          1
# 40316  NaN   326687501  ...       USN                          1
# ...    ...         ...  ...       ...                        ...
# 40525  NaN   326687501  ...       USN                          1
# 40526  NaN   326687501  ...       USN                          1
# 40527  NaN   326687501  ...       USN                          1
# 40528  NaN   326687501  ...       USN                          1
# 40529  NaN   326687501  ...       USN                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 40312                United States                          NaN
# 40313                United States                          NaN
# 40314                United States                          NaN
# 40315                United States                          NaN
# 40316                United States                          NaN
# ...                            ...                          ...
# 40525                United States                          NaN
# 40526                United States                          NaN
# 40527                United States                          NaN
# 40528                United States                          NaN
# 40529                United States                          NaN
#
#        administrative_area_level_3  latitude  longitude  key  \
# 40312                          NaN      38.0      -97.0  NaN
# 40313                          NaN      38.0      -97.0  NaN
# 40314                          NaN      38.0      -97.0  NaN
# 40315                          NaN      38.0      -97.0  NaN
# 40316                          NaN      38.0      -97.0  NaN
# ...                            ...       ...        ...  ...
# 40525                          NaN      38.0      -97.0  NaN
# 40526                          NaN      38.0      -97.0  NaN
# 40527                          NaN      38.0      -97.0  NaN
# 40528                          NaN      38.0      -97.0  NaN
# 40529                          NaN      38.0      -97.0  NaN
#
#        key_apple_mobility  key_google_mobility
# 40312       United States                   US
# 40313       United States                   US
# 40314       United States                   US
# 40315       United States                   US
# 40316       United States                   US
# ...                   ...                  ...
# 40525       United States                   US
# 40526       United States                   US
# 40527       United States                   US
# 40528       United States                   US
# 40529       United States                   US
#
# [218 rows x 35 columns]

# %%
# plot confirmed
plt.plot(usa["date"], usa["confirmed"], "r")
# format plot
plt.gcf().autofmt_xdate()
plt.suptitle("Confirmed cases of Covid-19 in USA", size=16)
plt.box(on=None)
plt.show()

# %%
# plots
plt.plot(usa["date"], usa["deaths"], "k")
plt.plot(usa["date"], usa["recovered"], "y")
# format plot
plt.gcf().autofmt_xdate()
plt.suptitle("Recovered and deaths of Covid-19 in USA", size=16)
plt.box(on=None)
plt.show()

# %% [markdown]
# Level sets the unit:
#
# 1. Country (default)
# 2. State | Region | Canton
# 3. City | Municipality | District
#
# In the case of USA, level 1 stands for country (federation) and level 2 stands for states.

# %%
usa2,usa2_src = covid19("USA", level = 2, verbose = False) # fetch US states data

# %% [markdown]
# The parameter `verbose` controls the message output.

# %%
usa2
# Out:
#               id       date     tests  confirmed  recovered  deaths   hosp  \
# 8101    121cd66e 2020-03-06      37.0        1.0        NaN     NaN    NaN
# 8102    121cd66e 2020-03-07      50.0        2.0        NaN     NaN    NaN
# 8103    121cd66e 2020-03-08      50.0        2.0        NaN     NaN    NaN
# 8104    121cd66e 2020-03-09      85.0        5.0        NaN     NaN    NaN
# 8105    121cd66e 2020-03-10     143.0       11.0        NaN     NaN    NaN
# ...          ...        ...       ...        ...        ...     ...    ...
# 110744  fb98cb76 2020-08-22  649443.0    54586.0     5791.0  1815.0  236.0
# 110745  fb98cb76 2020-08-23  649740.0    54883.0     5804.0  1815.0  258.0
# 110746  fb98cb76 2020-08-24  650000.0    55143.0     5823.0  1815.0  225.0
# 110747  fb98cb76 2020-08-25  650198.0    55341.0     5841.0  1824.0  243.0
# 110748  fb98cb76 2020-08-26  682061.0    55800.0     5867.0  1826.0  243.0
#
#         vent  icu  population  ...  administrative_area_level_1  \
# 8101     NaN  NaN   5639632.0  ...                United States
# 8102     NaN  NaN   5639632.0  ...                United States
# 8103     NaN  NaN   5639632.0  ...                United States
# 8104     NaN  NaN   5639632.0  ...                United States
# 8105     NaN  NaN   5639632.0  ...                United States
# ...      ...  ...         ...  ...                          ...
# 110744   NaN  NaN   5758736.0  ...                United States
# 110745   NaN  NaN   5758736.0  ...                United States
# 110746   NaN  NaN   5758736.0  ...                United States
# 110747   NaN  NaN   5758736.0  ...                United States
# 110748   NaN  NaN   5758736.0  ...                United States
#
#         administrative_area_level_2  administrative_area_level_3   latitude  \
# 8101                      Minnesota                          NaN  44.528372
# 8102                      Minnesota                          NaN  44.528372
# 8103                      Minnesota                          NaN  44.528372
# 8104                      Minnesota                          NaN  44.528372
# 8105                      Minnesota                          NaN  44.528372
# ...                             ...                          ...        ...
# 110744                     Colorado                          NaN  37.755612
# 110745                     Colorado                          NaN  37.755612
# 110746                     Colorado                          NaN  37.755612
# 110747                     Colorado                          NaN  37.755612
# 110748                     Colorado                          NaN  37.755612
#
#          longitude  key  key_google_mobility  key_apple_mobility  key_alpha_2  \
# 8101    -92.308909  NaN            Minnesota           Minnesota           MN
# 8102    -92.308909  NaN            Minnesota           Minnesota           MN
# 8103    -92.308909  NaN            Minnesota           Minnesota           MN
# 8104    -92.308909  NaN            Minnesota           Minnesota           MN
# 8105    -92.308909  NaN            Minnesota           Minnesota           MN
# ...            ...  ...                  ...                 ...          ...
# 110744 -102.289687  NaN             Colorado            Colorado           CO
# 110745 -102.289687  NaN             Colorado            Colorado           CO
# 110746 -102.289687  NaN             Colorado            Colorado           CO
# 110747 -102.289687  NaN             Colorado            Colorado           CO
# 110748 -102.289687  NaN             Colorado            Colorado           CO
#
#         key_numeric
# 8101            NaN
# 8102            NaN
# 8103            NaN
# 8104            NaN
# 8105            NaN
# ...             ...
# 110744          NaN
# 110745          NaN
# 110746          NaN
# 110747          NaN
# 110748          NaN
#
# [9785 rows x 37 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# plot each state separately
for state, data in usa2.groupby("administrative_area_level_2"):
    data = usa2[usa2["administrative_area_level_2"] == state]
    ax.plot(data["date"], data["confirmed"], label = state)
    ax.text(data["date"].iloc[-1], data["confirmed"].iloc[-1], state, fontsize=7)
# format plot
fig.suptitle("Confirmed cases of Covid-19 in US States", size = 16)
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fancybox = False, ncol = 8, prop={'size': 9})
plt.gcf().autofmt_xdate()
plt.box(on=None)
fig.show()

# %%
# get maximal record
usa2[ usa2["confirmed"] == max(usa2["confirmed"]) ]
# Out:
#              id       date       tests  confirmed  recovered   deaths    hosp  \
# 13164  1c20e671 2020-08-26  10832757.0   679099.0        NaN  12407.0  5537.0
#
#        vent     icu  population  ...  administrative_area_level_1  \
# 13164   NaN  1507.0  39512223.0  ...                United States
#
#        administrative_area_level_2  administrative_area_level_3   latitude  \
# 13164                   California                          NaN  36.582496
#
#         longitude  key  key_google_mobility  key_apple_mobility  key_alpha_2  \
# 13164 -116.704308  NaN           California          California           CA
#
#        key_numeric
# 13164          NaN
#
# [1 rows x 37 columns]

# %% [markdown]
# ## Filtering
#
# Except for country, the function also filters by start date and end date.

# %%
x,src = covid19(["ES","italy"], start="2020-03-01", end="2020-04-30", verbose=False)

# %% [markdown]
# Previous query shows only data between `2020-03-01` to `2020-03-31` from Spain and Italy.

# %%
x
# Out:
#         id       date      tests  confirmed  recovered   deaths     hosp  \
# 12709  ESP 2020-03-01        NaN       84.0        2.0      0.0      NaN
# 12710  ESP 2020-03-02        NaN      120.0        2.0      0.0      NaN
# 12711  ESP 2020-03-03        NaN      165.0        2.0      1.0      NaN
# 12712  ESP 2020-03-04        NaN      222.0        2.0      2.0      NaN
# 12713  ESP 2020-03-05        NaN      259.0        2.0      3.0      NaN
# ...    ...        ...        ...        ...        ...      ...      ...
# 19525  ITA 2020-04-26  1757659.0   197675.0    64928.0  26644.0  23381.0
# 19526  ITA 2020-04-27  1789662.0   199414.0    66624.0  26977.0  22309.0
# 19527  ITA 2020-04-28  1846934.0   201505.0    68941.0  27359.0  21586.0
# 19528  ITA 2020-04-29  1910761.0   203591.0    71252.0  27682.0  21005.0
# 19529  ITA 2020-04-30  1979217.0   205463.0    75945.0  27967.0  19843.0
#
#        vent     icu  population  ...  currency  administrative_area_level  \
# 12709   NaN     NaN    46796540  ...       EUR                          1
# 12710   NaN     NaN    46796540  ...       EUR                          1
# 12711   NaN     NaN    46796540  ...       EUR                          1
# 12712   NaN     NaN    46796540  ...       EUR                          1
# 12713   NaN     NaN    46796540  ...       EUR                          1
# ...     ...     ...         ...  ...       ...                        ...
# 19525   NaN  2009.0    60421760  ...       EUR                          1
# 19526   NaN  1956.0    60421760  ...       EUR                          1
# 19527   NaN  1863.0    60421760  ...       EUR                          1
# 19528   NaN  1795.0    60421760  ...       EUR                          1
# 19529   NaN  1694.0    60421760  ...       EUR                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 12709                        Spain                          NaN
# 12710                        Spain                          NaN
# 12711                        Spain                          NaN
# 12712                        Spain                          NaN
# 12713                        Spain                          NaN
# ...                            ...                          ...
# 19525                        Italy                          NaN
# 19526                        Italy                          NaN
# 19527                        Italy                          NaN
# 19528                        Italy                          NaN
# 19529                        Italy                          NaN
#
#        administrative_area_level_3  latitude  longitude  key  \
# 12709                          NaN      40.0       -4.0  NaN
# 12710                          NaN      40.0       -4.0  NaN
# 12711                          NaN      40.0       -4.0  NaN
# 12712                          NaN      40.0       -4.0  NaN
# 12713                          NaN      40.0       -4.0  NaN
# ...                            ...       ...        ...  ...
# 19525                          NaN      43.0       12.0  NaN
# 19526                          NaN      43.0       12.0  NaN
# 19527                          NaN      43.0       12.0  NaN
# 19528                          NaN      43.0       12.0  NaN
# 19529                          NaN      43.0       12.0  NaN
#
#        key_apple_mobility  key_google_mobility
# 12709               Spain                   ES
# 12710               Spain                   ES
# 12711               Spain                   ES
# 12712               Spain                   ES
# 12713               Spain                   ES
# ...                   ...                  ...
# 19525               Italy                   IT
# 19526               Italy                   IT
# 19527               Italy                   IT
# 19528               Italy                   IT
# 19529               Italy                   IT
#
# [122 rows x 35 columns]

# %%
# plot each state separately
for country in x.groupby("administrative_area_level_1").groups:
    data = x[x["administrative_area_level_1"] == country]
    plt.plot(data["date"], data["confirmed"], label = country)
# format plot
plt.gcf().autofmt_xdate()
plt.suptitle("Confirmed cases of Covid-19 in Italy and Spain", size = 16)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fancybox = False, ncol = 8, prop={'size': 9})
plt.box(on=None)
plt.show()

# %% [markdown]
# ## Vintage
#
# The datahub generates daily snapshots of the datasets. Fetch the version from given day by setting `vintage` to `True` and `end` to the desired date.

# %%
x, src = covid19("USA", end = "2020-04-22", vintage = True, verbose = False)

# %% [markdown]
# The vintage data are collected at the end of the day, but published with approximately 48 hour delay, once the day is completed in all the timezones.
#
# Hence if `vintage = True`, but `end` is not set, warning is raised and `None` is returned.

# %%
x, src = covid19("USA", vintage = True) # too early to get today's vintage
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-e3adde59b514> in <module>
# ----> 1 x, src = covid19("USA", vintage = True) # too early to get today's vintage
#
# TypeError: cannot unpack non-iterable NoneType object
